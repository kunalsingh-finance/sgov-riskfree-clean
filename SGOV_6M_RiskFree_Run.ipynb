# %%
import sys
print(sys.executable)

import yfinance, pandas, numpy, matplotlib
print("packages OK")
# Out:
# C:\Users\perso\OneDrive\Documents\sgov-riskfree-clean\.venv\Scripts\python.exe
# packages OK

# %%
import os
print(os.getcwd())
print(os.listdir())
# Out:
# C:\Users\perso\OneDrive\Documents\sgov-riskfree-clean
# ['.git', '.gitignore', '.ipynb_checkpoints', '.venv', 'README.md', 'requirements.txt', 'sgov_rf_6m.py', 'Untitled.ipynb']

# %%
# %run sgov_rf_6m.py --start 2024-01-01 --end 2026-02-10 --window 126 --out out --plot
# Out:
# DONE
# Latest date: 2026-02-09 00:00:00
# Latest rf_6m_simple_clipped: 0.019793
# Outputs saved in: C:\Users\perso\OneDrive\Documents\sgov-riskfree-clean\out

# %%
import glob
glob.glob("out/*")
# Out:
# ['out\\rf_latest.csv',
#  'out\\rf_latest.txt',
#  'out\\sgov_rf_6m.csv',
#  'out\\sgov_rf_6m.png',
#  'out\\sgov_rf_6m.xlsx']

# %%
import pandas as pd

df = pd.read_csv("out/sgov_rf_6m.csv")
df.tail()
# Out:
#            Date   Adj Close  daily_log_return  rf_6m_log_raw  \
# 397  2026-02-03  100.389999          0.000199       0.019699
# 398  2026-02-04  100.400002          0.000100       0.019699
# 399  2026-02-05  100.400002          0.000000       0.019599
# 400  2026-02-06  100.430000          0.000299       0.019898
# 401  2026-02-09  100.449997          0.000199       0.019600
#
#      rf_6m_simple_raw  rf_6m_simple_clipped
# 397          0.019894              0.019894
# 398          0.019894              0.019894
# 399          0.019793              0.019793
# 400          0.020098              0.020098
# 401          0.019793              0.019793

# %%
import pandas as pd

df = pd.read_csv("out/sgov_rf_6m.csv")
df.tail()
# Out:
#            Date   Adj Close  daily_log_return  rf_6m_log_raw  \
# 397  2026-02-03  100.389999          0.000199       0.019699
# 398  2026-02-04  100.400002          0.000100       0.019699
# 399  2026-02-05  100.400002          0.000000       0.019599
# 400  2026-02-06  100.430000          0.000299       0.019898
# 401  2026-02-09  100.449997          0.000199       0.019600
#
#      rf_6m_simple_raw  rf_6m_simple_clipped
# 397          0.019894              0.019894
# 398          0.019894              0.019894
# 399          0.019793              0.019793
# 400          0.020098              0.020098
# 401          0.019793              0.019793

# %%
with open("out/rf_latest.txt", "r") as f:
    print(f.read())
# Out:
# Date: 2026-02-09 00:00:00
# rf_6m_simple_clipped: 0.019793
